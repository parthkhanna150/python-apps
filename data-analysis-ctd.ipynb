# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  '.git',
#  '.ipynb_checkpoints',
#  'desktop-db-app',
#  'dictionary',
#  'geocoder-webservice',
#  'motion-detector',
#  'README.md',
#  'real-estate-scraper',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Udemy stuff.ipynb',
#  'Untitled.ipynb',
#  'web-finance-graph',
#  'webmaps-folium',
#  'website-blocker',
#  'website-flask',
#  'website-postgreSQL-flask']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
df6 = pandas.read_json("https://pythonhow.com/supermarkets.json")
df6
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df6=df6.set_index("Address")
# just doing df6.set_index is temp. need to store this in a var for later purposes on this df

# %%
df6
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df6.loc["735 Dolores St", "Country":"ID"]
# first is range of index columns
# Out:
# Country      USA
# Employees     15
# ID             2
# Name: 735 Dolores St, dtype: object

# %%
list(df6.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df6.loc["735 Dolores St":"332 Hill St", "Country":"ID"]
# first is range of index column-names
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3

# %%
df6.iloc[1:4,1:3]
# Out:
#                Country  Employees
# Address
# 735 Dolores St     USA         15
# 332 Hill St        USA         25
# 3995 23rd St       USA         10

# %%
df6.iloc[3,1:4]
# Out:
# Country      USA
# Employees     10
# ID             4
# Name: 3995 23rd St, dtype: object

# %%
df6.ix[3,4]
#not recommended over loc and iloc though
# Out:
# /Users/vasu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# "Ben's Shop"

# %%
df6.drop("City", 1)
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df6
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df6.drop("3666 21st St",0)
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df6.drop(df6.index[0:3],0)
# Out:
#                           City Country  Employees  ID        Name       State
# Address
# 3995 23rd St     San Francisco     USA         10   4  Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5     Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6  Richvalley    CA 94114

# %%
df6
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df6.drop(df6. columns[0:3],1)
# Out:
#                  ID         Name             State
# Address
# 3666 21st St      1      Madeira          CA 94114
# 735 Dolores St    2  Bready Shop          CA 94119
# 332 Hill St       3  Super River  California 94114
# 3995 23rd St      4   Ben's Shop          CA 94114
# 1056 Sanchez St   5      Sanchez        California
# 551 Alvarado St   6   Richvalley          CA 94114

# %%
df6.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df6.columns
# Out:
# Index(['City', 'Country', 'Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df7=df6

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df7["Continent"]=["North America"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-f01d834fdaa6> in <module>()
# ----> 1 df7["Continent"]=["North America"]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
#    2759             # turn me into an ndarray
# ...

# %%
df7["Continent"]=df7.shape[0]*["North America"]

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State          Continent
# Address
# 3666 21st St             CA 94114  USA,North America
# 735 Dolores St           CA 94119  USA,North America
# 332 Hill St      California 94114  USA,North America
# 3995 23rd St             CA 94114  USA,North America
# 1056 Sanchez St        California  USA,North America
# 551 Alvarado St          CA 94114  USA,North America

# %%
df7["Continent"]=df7["Country"]+","+df7["Continent"]
# putting a column is trivial
# to put a row, transpose it put a column then transpose again to get the desired

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State          Continent
# Address
# 3666 21st St             CA 94114  USA,North America
# 735 Dolores St           CA 94119  USA,North America
# 332 Hill St      California 94114  USA,North America
# 3995 23rd St             CA 94114  USA,North America
# 1056 Sanchez St        California  USA,North America
# 551 Alvarado St          CA 94114  USA,North America

# %%
df7_t=df7.T

# %%
df7_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                 10                 12                 20
# ID                         4                  5                  6
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df7_t["332 Hill St"] = ["My City", "My Country", 10, 7, "My Shop", "My Stats", "My Continent"]

# %%
df7 = df7_t.T

# %%
df7
# Out:
#                           City     Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco         USA         8  1      Madeira
# 735 Dolores St   San Francisco         USA        15  2  Bready Shop
# 332 Hill St            My City  My Country        10  7      My Shop
# 3995 23rd St     San Francisco         USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco         USA        12  5      Sanchez
# 551 Alvarado St  San Francisco         USA        20  6   Richvalley
# My Address             My City  My Country        10  7      My Shop
#
#                       State          Continent
# Address
# 3666 21st St       CA 94114  USA,North America
# 735 Dolores St     CA 94119  USA,North America
# 332 Hill St        My Stats       My Continent
# 3995 23rd St       CA 94114  USA,North America
# 1056 Sanchez St  California  USA,North America
# 551 Alvarado St    CA 94114  USA,North America
# My Address         My Stats       My Continent

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.75298458728149

# %%
n.longitude
# Out:
# -122.4317017142651

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75644449321933, -122.42935314363206, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.75644449321933

# %%
df["Latitude"]=df["Coordinates"].latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-cbaefb4489a1> in <module>()
# ----> 1 df["Latitude"]=df["Coordinates"].latitude
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'latitude'

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x!=None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x!=None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
